# %% [markdown]
# # SM-KIDs LaTeX-aften 2026
#
# Kære rus, du vil i denne Jupyter Notebook blive introduceret til Jupyter Notebooks som koncept og redskab.
#
# Hurtigt om Jupyter Notebooks:
# - Jupyter Notebooks har filformatet `.ipynb` - og forkortes ligeledes ofte ***ipynb***
#
# - Kombinerer Python (et programmeringssprog) og Markdown (et markup-/formateringssprog)
#     - Består derfor af *kode-felter* og *markdown-felter*
# - (Hvor bruges de, og hvorfor er de smarte)
#
# Læs denne Notebook kronologisk i gennem, lav øvelserne undervejs og afslut med opgaverne - og husk for guds skyld at bede om hjælp og stille spørgsmål undervejs.

# %% [markdown]
# ## Indhold
#
# 1. Opbygning, redigering og navigation
#
# 2. Introduktion til Markdown
# 3. Øvelser

# %% [markdown]
# ## Opbygning, redigering og navigation
#
# En Jupyter Notebook består som sagt af hhv. Markdown- og kodefelter. Man kan oprette, redigere, fjerne og flytte rundt på felter som man har lyst til.
#
# I kodefelterne skriver man - sjovt nok, - kode i form af Python. Kodefelterne eksekveres hver for sig, men alle felter kan også eksekveres én efter én ved trykke på `Run All/Kør alle`-knappen i toppen af VS-Code.
#
# Modsat en alm. Python-fil, skal man være lidt opmærksom på eksekveringsrækkefølgen; Har man kørt et felt, skal man f.eks. være opmærksom på, at variabler i dette felt nu også er gældende i de resterende felter (både over/under) - hvorfor det er smart at kende til `Run All/Kør alle`-knappen i toppen, således at alle felter (og dermed også variabler) eksekveres kronologisk.
#
# I Markdown-felterne skriver man naturligvis Markdown --- mere om dette senere.
#
# Når man har markeret/"er i et" felt, kan man befinde sig i to tilstande; ***Command Mode*** og ***Edit Mode***.
#
# ***Command Mode*** kan du bruge tastaturgenveje til at manipulere dokumentet og samtidig vil f.eks. Markdown også være formateret pænt. Man bruger ofte denne tilstand når man skal "se/kigge på" feltet.
#
# ***Edit Mode*** bruges når man redigere et felts indhold --- derfor vil man også se den "rå" Markdown-kode og ikke den pæne og formaterede version. Prøv f.eks. at trykke `ENTER` eller dobbeltklikke på dette felt. For at komme tilbage, tryk på fluebenet i feltets højre øverste hjørne eller tryk `ESC`.
#
# ### Overblik over tastaturgenveje
#
# Tastaturgeneveje kan være besværlige og irriterende at lære, men de gør dit arbejde væsentligt lettere og hurtigere - så tving dig selv til at bruge dem og lære dem!
#
# Vær opmærksom på at enkelte genveje adskiller sig afhængigt af dit OS (MacOS/Windows/Linux) - prøv dig frem, så finder du mønstret.
#
# Du finder overblikket over tastaturgenveje [her](https://jupyter-tutorial.readthedocs.io/en/24.1.0/notebook/shortcuts.html).

# %% [markdown]
# ## Introduktion til Markdown
#
# Nu har vi nævnt Markdown en del gange, men endnu ikke præciseret eller forklaret hvad det er.
#
# Markdown er en måde at formatere tekst på. I Word eller Google Docs er man vant til at bruge knapper til at gøre ting fede, ændre skriftstørrelse, etc. I Markdown skriver man det direkte sammen med indholdet/teksten - derfor kaldes det er et Markupsprog. Derfor skal Markdown også vises i et miljø der kan oversætte Markdown --- f.eks. en Jupyter Notebook. Man kan også skrive rene Markdown-filer, disse ender på `.md`.
#
# Overskrifter markeres med `#`. Et enkelt `#` betyder den største overskrift. 2 `#` den næst største osv.
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
#
# Tekst kan skrives `italic` ved at omklamre dem med `*`, altså bliver `*Slagelse*` til *Slagelse*.
# Ved `bold` bruger man `**`, altså bliver `**Slagelse**` til **Slagelse**.
# `bold` og `italic` benytter man blot tre, altså bliver `***Slagelse***` til ***Slagelse***.
#
# Man kan tilføje et kode lignende felt til tekst som her: `Hej` ved at skrive \`Hej\`. Man kan også tilføje skjulte kommentarer ved at skrive \<!--Tekst-->. <!--Kommentar-->
#
# Dertil kan man tilføje links i sin Markdown tekst ved at skrive \[Hyperlink tekst\]\(URL\). F.eks. ved at klikke på følgende "her": [her](https://jupyter-tutorial.readthedocs.io/en/24.1.0/notebook/shortcuts.html), så følger man linket til tastaturgenvejende.
#
# Se følgende link for resterende syntax regler: [her](https://www.markdownguide.org/cheat-sheet/).
#
# **Protip:** Du kan skrive LaTeX direkete i markdown ved at bruge `$` --- `$<LaTeX på en linje>$`, `$$<LaTeX på tværs af flere linjer>$$`.
#
# **Protip:** Markdown er meget mere token efficient end f.eks. PDF'er, når du skal have diverse LLM'er til at lave dine ting.

# %% [markdown]
# ## Øvelser

# %% [markdown]
# Kør først følgende kode:

# %%
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %% [markdown]
# Dernæst tilføj et nyt Markdown-felt herunder og i det skriv dit navn, din studieretning og dagens dato (22/09-2026) over tre linjer.

# %% [markdown]
# Lav en kode-celle herunder, som indeholder 2+3 på den første linje, kør cellen og notér hvad resultatet bliver.
#
# Tilføj efterfølgende en ny linje og skriv 6*7, kør cellen igen og notér hvad resultatet bliver.

# %% [markdown]
# I nedenstående kode-celle er der flere regnestykker på flere forskellige linjer. Prøv denne gang at tilføje print() til hver linje og sætte regnestykket ind i parentes. Er det forskelligt fra ovenstående opgave og i så fald - hvorfor?

# %%
10+5
10-5
10*5
10/5
# Out:
# 2.0

# %% [markdown]
# I nedenstående kode-celle er der en variabel - "name". Variablens værdi er lige nu Indsæt navn her. Ændre variables værdi fra Indsæt navn her til dit eget navn og kør cellen.

# %%
name = "Indsæt navn her"
print("Hej", name)
# Out:
# Hej Indsæt navn her

# %% [markdown]
# Ved at køre ovenstående kode-celle, så sættes variablens værdi. Denne værdi gemmes og kan bruges i andre kode-celler.
#
# Lav nu en ny kode-celle og skriv blot name deri. Derefter kør cellen og bemærk resultatet.

# %% [markdown]
# Herefter skal du genstarte din "notebook kernel". Det gøres ved at klikke på Restart eller Genstart knappen i toppen af din editor. Efter du har genstartet din kernel, prøv så at køre ovenstående kode-celle igen og bemærk resultatet.

# %% [markdown]
# Benyt nu nedenstående kode udsnit til at beregne arealet af et rektangel (med bredde 10 og længde 2.5) ved at indsætte de rigtige værdier i variablene og køre koden.

# %%
width = 10
height = 2.5
area = width * height

print(area)
# Out:
# 25.0

# %% [markdown]
# Herefter skal du oprette en ny kode-celle nedenfor og importere en pakke. Opret først kode-cellen og skriv "import numpy as np" på første linje. Hermed er numpy importeret og du kan benytte det. Benyt nu numpy til at finde kvadratroden af ovenstående rektangels areal.

# %% [markdown]
# Herefter skal vi benytte pi, som er en del af numpy, til at finde omkredsen af en cirkel med diameter 21.5. Lav en ny kode-celle nedenfor og beregn omkredsen.

# %% [markdown]
# ## Det var det
#
# Godt gået rus, du har nu stiftet bekendtskab med Jupyter Notebooks og Markdown (MD).
#
# Det er usandsynligt, at du nu allerede er fuldstændig komfortabel med Jupyter Notebooks - men du kommer heldigvis til at møde dem igen en gang eller to, i løbet af din studietid.
#
# Har du imidlertid lyst til selv at lære mere, kan du med fordel orientere dig i den [officielle dokumenation](https://docs.jupyter.org/en/latest/) eller kigge på [VS Code's egen guide](https://code.visualstudio.com/docs/datascience/jupyter-notebooks).
#
# Vi håber du har haft gavn af introduktionen :-)

# %% [markdown]
# ## (Egne noter)

# %% [markdown]
# a - nyt felt ovenover
#
# b - myt felt nedeunder
#
# naviger i felter med piletester
#
# rediger felt med enter (alternativ dobbeltklik på felter, brug menuen til venstre i felterne)
#
# forlad felt med esc
#
# lav felt til markdown med m
#
# lav felt til kode med y
#
# kollaps output med o
#
# ctrl + shift + - (split celler ved cursor)
#
# flyt rundt på felter med mus

# %% [markdown]
# kør felt med ctrl (shift, alt) enter
#
# opt/ctrl + click (multiple cursor)
#
# to tilstande: navigation/visning og edit mode
#
# husk at gemme jævnligt
